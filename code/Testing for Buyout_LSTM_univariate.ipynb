# %%
from data_processing import *
from evaluation import evaluation_model
from model import build_model

# %%
dat_all = get_macro(filename, "All")
dataset = dat_all
X = trans_dat(dataset)
y = prep_dat(dat_all)['Q_Next']
X_train, X_test = split_dataset_x(X)
y_train, y_test = split_dataset_y(y)

# %%
model_uni_lstm = build_model(X_train,y_train,270)

# %%
evaluation_model(model_uni_lstm,X_train,X_test,y_train,y_test)
# Out:
# Train set MSE is 0.0006029628702737571
# Test set MSE is 0.004255755498956152
